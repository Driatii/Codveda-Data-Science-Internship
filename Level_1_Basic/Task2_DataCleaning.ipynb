# %%
import pandas as pd


df = pd.read_csv('../Datasets/Churn Prdiction Data/churn-bigml-80.csv')


df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
# %pip install scikit-learn

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

df = pd.read_csv('../Datasets/Churn Prdiction Data/churn-bigml-80.csv')

for col in df.columns:
    if df[col].dtype in ['int64', 'float64']:
        df[col] = df[col].fillna(df[col].median())
    else:
        df[col] = df[col].fillna(df[col].mode()[0])

numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
Q1 = df[numeric_cols].quantile(0.25)
Q3 = df[numeric_cols].quantile(0.75)
IQR = Q3 - Q1
mask = ~((df[numeric_cols] < (Q1 - 1.5 * IQR)) | (df[numeric_cols] > (Q3 + 1.5 * IQR))).any(axis=1)
df_cleaned = df[mask].copy()

categorical_cols = df_cleaned.select_dtypes(include=['object', 'bool']).columns
df_cleaned = pd.get_dummies(df_cleaned, columns=categorical_cols, drop_first=True)

scaler = StandardScaler()
final_numeric = df_cleaned.select_dtypes(include=['int64', 'float64', 'float32']).columns
df_cleaned[final_numeric] = scaler.fit_transform(df_cleaned[final_numeric])

df_cleaned.to_csv('Task2_Cleaned_Churn_Data.csv', index=False)
print("Task 2 Complete! Cleaned data saved.")
df_cleaned.head()
# Out:
# Task 2 Complete! Cleaned data saved.
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_19328\1307010894.py:20: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_cols = df_cleaned.select_dtypes(include=['object', 'bool']).columns
#    Account length  Area code  Number vmail messages  Total day minutes  \
# 0        0.714450  -0.531088               1.242684           1.621338
# 1        0.177014  -0.531088               1.316042          -0.350505
# 2        0.944780  -0.531088              -0.591277           1.207918
# ...
